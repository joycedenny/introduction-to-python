# %% [markdown]
# <a href="https://colab.research.google.com/github/joycedenny/introduction-to-python/blob/main/intoduction%20to%20python%2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-a601c602-af11-4f47-a337-cd9d24e8f914" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a601c602-af11-4f47-a337-cd9d24e8f914">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-ecf60e6f-b5e4-48bb-aadf-93357f4c1296" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecf60e6f-b5e4-48bb-aadf-93357f4c1296">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
teamgoals={
    'teams':['spain','england'],
    'goals':[2,4]
}
teamgoaldf= pd.DataFrame(teamgoals)  
print(teamgoaldf)
# Out:
#      teams  goals
# 0    spain      2
# 1  england      4

# %%
import pandas as pd
team={'country':['brazil','argentina','portugal'],'player':['neymar','messi','ronaldo']}
df=pd.DataFrame(team)
print(df)
# Out:
#      country   player
# 0     brazil   neymar
# 1  argentina    messi
# 2   portugal  ronaldo

# %%
import pandas as pd
grade={'name':['annjalina','ann','merin'],'marks':['20','30','40']}
df=pd.DataFrame(grade)
print(df)
# Out:
#         name marks
# 0  annjalina    20
# 1        ann    30
# 2      merin    40

# %%
import pandas as pd
df=pd.read_csv("Supermarket_sales.csv")
print(df)
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
import pandas as pd
df=pd.read_csv("Supermarket_sales.csv")
print(df)
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
import pandas as pd
df=pd.read_csv("Supermarket_sales.csv")
print(df.tail())
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax      Total       Date  \
# 995    Health and beauty      40.35         1   2.0175    42.3675  1/29/2019
# 996   Home and lifestyle      97.38        10  48.6900  1022.4900   3/2/2019
# 997   Food and beverages      31.84         1   1.5920    33.4320   2/9/2019
# 998   Home and lifestyle      65.82         1   3.2910    69.1110  2/22/2019
# 999  Fashion accessories      88.34         7  30.9190   649.2990  2/18/2019
#
#       Time  Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
import pandas as pd
df=pd.read_csv("Supermarket_sales.csv")
print(df['City'])
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
import pandas as pd
df=pd.read_csv("Supermarket_sales.csv")
print(df['City'],df['Branch'])
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
for i in df.index:
  print(df.City[i],df.Branch[i])
# Out:
# Yangon A
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Yangon A
# Naypyitaw C
# Mandalay B
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Mandalay B
# Mandalay B
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Naypyitaw C
# Mandalay B
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Naypyitaw C
# ...

# %%
from google.colab import files
players_20=files.upload()
# Out:
#      <input type="file" id="files-de5bf288-2004-4581-bc56-231da68758cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de5bf288-2004-4581-bc56-231da68758cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas
fifadf = pandas.read_csv("players_20.csv") 
max_overall=fifadf.overall.max() 
max_overall_loc = fifadf.overall.idxmax() 
person=fifadf.loc[max_overall_loc]
print(person.long_name,"has the highest overall of ",max_overall)
# Out:
# Lionel Andrés Messi Cuccittini has the highest overall of  94

# %%
import pandas
fifadf = pandas.read_csv("players_20.csv") 
min_age=fifadf.age.min() 
min_age_loc = fifadf.age.idxmin() 
person=fifadf.loc[min_age_loc]
print(person.long_name,"is the youngest player and is ",min_age)
# Out:
# Adam Hložek is the youngest player and is  16

# %%
import pandas
fifadf = pandas.read_csv("players_20.csv") 
max_age=fifadf.age.max() 
max_age_loc = fifadf.age.idxmax() 
person=fifadf.loc[max_age_loc]
print(person.long_name,"is the oldest player and is ",max_age)
# Out:
# Cristian Fernando Muñoz Hoffman is the oldest player and is  42

# %%
fifadf = pandas.read_csv("players_20.csv")
playercount = fifadf.sofifa_id.count()
print(playercount)
# Out:
# 18278

# %%
import pandas
fifadf = pandas.read_csv("players_20.csv") 
for i in fifadf.index:
  if fifadf.club[i] == "FC Barcelona":
    print(fifadf.short_name[i])
# Out:
# L. Messi
# M. ter Stegen
# L. Suárez
# Sergio Busquets
# A. Griezmann
# Piqué
# Jordi Alba
# S. Umtiti
# I. Rakitić
# F. de Jong
# C. Lenglet
# Neto
# O. Dembélé
# Arthur
# A. Vidal
# Nélson Semedo
# Sergi Roberto
# Rafinha
# Junior Firpo
# Aleñá
# Riqui Puig
# J. Todibo
# M. Wagué
# H. Abe
# L. Reis
# Abel Ruiz
# Oriol Busquets
# Carles Pérez
# Miranda
# Chumi
# Álex Collado
# Jorge Cuenca
# Iñaki Peña
