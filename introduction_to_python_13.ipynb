# %% [markdown]
# <a href="https://colab.research.google.com/github/joycedenny/introduction-to-python/blob/main/introduction_to_python_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file1=files.upload()
# Out:
#      <input type="file" id="files-06f5267c-b228-4a8d-86f2-d51e96a09856" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06f5267c-b228-4a8d-86f2-d51e96a09856">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df= pd.read_csv("cups of coffee vs hours of sleep.csv")

# %%
import numpy as np
import plotly.express as px
fig= px.line(df, x="Coffee in ml", y="sleep in hours")
fig.update_yaxes(rangemode="tozero")
fig.show()
print("Correlation factor= ",np.corrcoef(df['Coffee in ml'],df['sleep in hours']))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# application:
#
# we can use this information for
# - medical purpuses
# - research purposes
# - it can be used by students during exam time to boost their productivity with lesser sleep
# - it can be used by organisations to boost workers productivity
#
# how i did this code:
#
# - i imported the file and read the code
#
# - i used plotly express and i defined what i wanted for x and y axis in my line graph through the code
#
# - i wrote the command to write the correlation factor
#
# what i understood from this graph:
#
# - i understood that the higher the coffee intake the less sleepier the person becomes

# %%
from google.colab import files
file1=files.upload()
# Out:
#      <input type="file" id="files-30f4a921-073a-43f6-ae82-1c2a97c0832c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30f4a921-073a-43f6-ae82-1c2a97c0832c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df1= pd.read_csv("Size of TV,_Average time spent watching TV in a week (hours).csv")

# %%
import plotly.express as px
fig1= px.line(df1, x="Size of TV", y="\tAverage time spent watching TV in a week (hours)")
fig1.update_yaxes(rangemode="tozero")
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# application:
#
# we can use this to learn more about
# - behavioural studies
#
# - data collection about tv sizes
# - by retailers who'd like to know what will sell better to the public
#
# how i did this code:
#
# - i imported and read the file
#
#
# - i used plotly express and i defined what i wanted for x and y axis in my line graph through the code
#
# what i understood from this graph:
#
# - people with 15inch tvs watch it the most
#
# - people with 18inch tvs watch it the least
