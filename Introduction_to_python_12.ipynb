# %% [markdown]
# <a href="https://colab.research.google.com/github/joycedenny/introduction-to-python/blob/main/Introduction_to_python_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-b87ec463-a0c6-495b-9751-061a67a84eef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b87ec463-a0c6-495b-9751-061a67a84eef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df1=pd.read_csv("SOCR-HeightWeight.csv")
print(df1)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

height=df1["Height(Inches)"]
print("Mean Height of the class=",height.mean())
print("Mode Height of the class=",height.mode())
print("Median Height of the class=",height.median())

weight=df1["Weight(Pounds)"]
print("Mean Weight of the class=",weight.mean())
print("Mode Weight of the class=",weight.mode())
print("Median Weight of the class=",weight.median())

plt.scatter(height,weight,color="b")
plt.show()
# Out:
# Mean Height of the class= 67.99311359679999
# Mode Height of the class= 0     65.65796
# 1     67.34629
# 2     67.41672
# 3     67.94061
# 4     67.97769
# 5     67.98509
# 6     68.30287
# 7     68.92380
# 8     68.93456
# 9     68.97830
# 10    70.04724
# dtype: float64
# Median Height of the class= 67.9957
# Mean Weight of the class= 127.07942116080001
# Mode Weight of the class= 0    124.7975
# dtype: float64
# Median Weight of the class= 127.15775

# %% [markdown]
# we can use this information in the medical field for finding out health issues like obesity or malnourishment.

# %%
# Q2
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-c3bb4d2b-2325-45e6-b339-83c44bfa991e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3bb4d2b-2325-45e6-b339-83c44bfa991e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
dfC1=pd.read_csv("class1.csv")
dfC2=pd.read_csv("class2.csv")
print(dfC1)
print(dfC2)
# Out:
#     Student Number  Marks
# 0                1     20
# 1                2     69
# 2                3     56
# 3                4     90
# 4                5     40
# 5                6     99
# 6                7     86
# 7                8    100
# 8                9     70
# 9               10     69
# 10              11     80
# 11              12     65
# 12              13     57
# 13              14     82
# 14              15     90
# 15              16     70
# 16              17     79
# 17              18     39
# 18              19     90
# 19              20     80
# 20              21     86
# 21              22     53
# 22              23     97
# 23              24     95
# 24              25     88
# 25              26     47
# 26              27    100
# 27              28     56
# 28              29     97
# 29              30    100
#     Student Number  Marks
# 0                1     60
# 1                2     61
# 2                3     65
# ...

# %%
import numpy as np
dfC1=pd.read_csv("class1.csv")
dfC2=pd.read_csv("class2.csv")

xvalues1=(dfC1["Student Number"])
yvalues1=(dfC1["Marks"])
plt.bar(xvalues1,yvalues1,color="k")
plt.show()

xvalues2=(dfC2["Student Number"])
yvalues2=(dfC2["Marks"])
plt.bar(xvalues2,yvalues2,color="c")
plt.show()

# %%
#Q3
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-c66d732b-e260-464f-b3ad-ac42c894075b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c66d732b-e260-464f-b3ad-ac42c894075b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df3=pd.read_csv("Ice-Cream vs Cold-Drink vs Temperature - Ice Cream Sale vs Temperature data.csv")
print(df3)
# Out:
#     Temperature  Ice-cream Sales( ₹ )  Cold drink sales( ₹ )
# 0          14.2                 17200                  33900
# 1          16.4                 26000                  51300
# 2          11.9                 14800                  29300
# 3          15.2                 26560                  53020
# 4          18.5                 32480                  64560
# 5          22.1                 41760                  83420
# 6          19.4                 32960                  65320
# 7          25.1                 49120                  97040
# 8          23.4                 43520                  86040
# 9          18.1                 33680                  67060
# 10         22.6                 35600                  70700
# 11         17.2                 32640                  64880

# %%
import plotly.express as px

# %%
fig3= px.scatter(df3,x="Temperature",y="Ice-cream Sales( ₹ )")
fig3.update_yaxes(rangemode="tozero")
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Q4
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-349e4b39-2c73-469f-a1de-fcc54515feaa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-349e4b39-2c73-469f-a1de-fcc54515feaa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df4=pd.read_csv("Student Marks vs Days Present.csv")
print(df4)
# Out:
#     Roll No  Marks In Percentage  Days Present
# 0         1                79.00           180
# 1         2                73.00           160
# 2         3                71.00           155
# 3         4                71.60           156
# 4         5                59.59           145
# 5         6                30.00           122
# 6         7                35.00           131
# 7         8                44.00           156
# 8         9                60.00           166
# 9        10                60.00           170
# 10       11                60.00           155
# 11       12                63.00           158
# 12       13                78.00           170
# 13       14                63.00           160
# 14       15                77.00           165
# 15       16                54.00           159
# 16       17                20.00           119
# 17       18                65.00           168
# 18       19                78.00           175
# ...

# %%
df4=pd.read_csv("Student Marks vs Days Present.csv")
fig4=px.scatter(df4,x="Marks In Percentage",y="Days Present")
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
